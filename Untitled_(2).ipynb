# %% [markdown]
# <a href="https://colab.research.google.com/github/Ebrahimgreat/Couresa_test/blob/master/Untitled_(2).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [raw]
# import pandas as pd
# import numpy as np
#
# df=pd.read_csv('pokemon_data.csv')

# %% [raw]
# df.head(5)

# %%
df['Total']=df['Attack']+df['HP']+df['Defense']+df['Sp. Atk']+df['Speed']+df['Sp. Def']
df.to_csv('file1.csv')

# %%
df.head(5)
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary  Total
# 0       65     45           1      False    318
# 1       80     60           1      False    405
# 2      100     80           1      False    525
# 3      120     80           1      False    625
# 4       50     65           1      False    309

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.displot(df['Total'])
# Out:
# /Users/ebrahimarshad/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
#Some of the data is missing, so lets fix that
df.fillna('None',inplace=True)

# %%
df['Type 2']
# Out:
# 0      Poison
# 1      Poison
# 2      Poison
# 3      Poison
# 4        None
#         ...
# 795     Fairy
# 796     Fairy
# 797     Ghost
# 798      Dark
# 799     Water
# Name: Type 2, Length: 800, dtype: object

# %%
#Lets see the most Pokemon from a particular generation in our dataset
sns.lineplot(x=df['Generation'],y=df['Total'])
#Lets understand the strongest pokemon based on all stats
sns.title='StrongestPokemon'

# %%
Strongest=max(df['Total'])

# %%
print(Strongest)
# Out:
# 780

# %%
# %load_ext sql

# %%
# %reload_ext sql

# %%
# %sql sqlite:///your_database_name.db

# %%
# %sql
# Out:
#  * sqlite:///your_database_name.db

# %%
# %sql Create Table('Name', 'Age')
# Out:
#  * sqlite:///your_database_name.db
# (sqlite3.OperationalError) near "(": syntax error
# [SQL: Create Table('Name', 'Age' )]
# (Background on this error at: https://sqlalche.me/e/20/e3q8)

# %%
# %%sql CREATE TABLE StrongestPokemon (
#     name VARCHAR(100),
#     type 1 VARCHAR(100),
#     Generation int
# );
# Out:
#  * sqlite:///your_database_name.db
# (sqlite3.OperationalError) table StrongestPokemon already exists
# [SQL: CREATE TABLE StrongestPokemon (
#     name VARCHAR(100),
#     type 1 VARCHAR(100),
#     Generation int
# );]
# (Background on this error at: https://sqlalche.me/e/20/e3q8)

# %%
strongest_pokemon = df[df['Total'] ==Strongest]

# %%
type(strongest_pokemon)
# Out:
# pandas.core.frame.DataFrame

# %%
print(strongest_pokemon['Name'])
# Out:
# 163      MewtwoMega Mewtwo X
# 164      MewtwoMega Mewtwo Y
# 426    RayquazaMega Rayquaza
# Name: Name, dtype: object

# %%
# %sql Select name FROM strongestpokemon
# Out:
#  * sqlite:///your_database_name.db
# Done.
# [('MewtwoMega Mewtwo X',),
#  ('MewtwoMega Mewtwo Y',),
#  ('RayquazaMega Rayquaza',),
#  ('MewtwoMega Mewtwo X',),
#  ('MewtwoMega Mewtwo Y',),
#  ('RayquazaMega Rayquaza',),
#  ('MewtwoMega Mewtwo X',),
#  ('MewtwoMega Mewtwo Y',),
#  ('RayquazaMega Rayquaza',),
#  ('MewtwoMega Mewtwo X',),
#  ('MewtwoMega Mewtwo Y',),
#  ('RayquazaMega Rayquaza',),
#  ('MewtwoMega Mewtwo X',),
#  ('MewtwoMega Mewtwo Y',),
#  ('RayquazaMega Rayquaza',)]

# %%
# %sql SELECT * FROM strongestPokemon
# Out:
#  * sqlite:///your_database_name.db
# Done.
# [('MewtwoMega Mewtwo X', 'Psychic', 780, None),
#  ('MewtwoMega Mewtwo Y', 'Psychic', 780, None),
#  ('RayquazaMega Rayquaza', 'Dragon', 780, None),
#  ('MewtwoMega Mewtwo X', 'Psychic', 780, 1),
#  ('MewtwoMega Mewtwo Y', 'Psychic', 780, 1),
#  ('RayquazaMega Rayquaza', 'Dragon', 780, 3),
#  ('MewtwoMega Mewtwo X', 'Psychic', 780, 1),
#  ('MewtwoMega Mewtwo Y', 'Psychic', 780, 1),
#  ('RayquazaMega Rayquaza', 'Dragon', 780, 3),
#  ('MewtwoMega Mewtwo X', 'Psychic', 780, 1),
#  ('MewtwoMega Mewtwo Y', 'Psychic', 780, 1),
#  ('RayquazaMega Rayquaza', 'Dragon', 780, 3)]

# %%
# %%sql CREATE TABLE strongestPokemon(
#     name VARCHAR(100),
#     type VARCHAR(100),
#     total Integer,
#     Generation Integer
# );
# Out:
#  * sqlite:///your_database_name.db
# (sqlite3.OperationalError) table strongestPokemon already exists
# [SQL: CREATE TABLE strongestPokemon(
#     name VARCHAR(100),
#     type VARCHAR(100),
#     total Integer,
#     Generation Integer
# );]
# (Background on this error at: https://sqlalche.me/e/20/e3q8)

# %%
# %sql SELECT * from strongestpokemon
# Out:
#  * sqlite:///your_database_name.db
# Done.
# [('MewtwoMega Mewtwo X', 'Psychic', 780, None),
#  ('MewtwoMega Mewtwo Y', 'Psychic', 780, None),
#  ('RayquazaMega Rayquaza', 'Dragon', 780, None),
#  ('MewtwoMega Mewtwo X', 'Psychic', 780, 1),
#  ('MewtwoMega Mewtwo Y', 'Psychic', 780, 1),
#  ('RayquazaMega Rayquaza', 'Dragon', 780, 3),
#  ('MewtwoMega Mewtwo X', 'Psychic', 780, 1),
#  ('MewtwoMega Mewtwo Y', 'Psychic', 780, 1),
#  ('RayquazaMega Rayquaza', 'Dragon', 780, 3),
#  ('MewtwoMega Mewtwo X', 'Psychic', 780, 1),
#  ('MewtwoMega Mewtwo Y', 'Psychic', 780, 1),
#  ('RayquazaMega Rayquaza', 'Dragon', 780, 3),
#  ('MewtwoMega Mewtwo X', 'Psychic', 780, 1),
#  ('MewtwoMega Mewtwo Y', 'Psychic', 780, 1),
#  ('RayquazaMega Rayquaza', 'Dragon', 780, 3)]

# %%
# %sql Alter table pokemon ADD Generation Integer;
# Out:
#  * sqlite:///your_database_name.db
# (sqlite3.OperationalError) duplicate column name: Generation
# [SQL: Alter table pokemon ADD Generation Integer;]
# (Background on this error at: https://sqlalche.me/e/20/e3q8)

# %%
SELECT * from strongestPokemon
# Out:
#   Cell In[27], line 1
#     SELECT * from strongestPokemon
#              ^
# SyntaxError: invalid syntax

# %%
# %sql SELECT * from strongestPokemon
# Out:
#  * sqlite:///your_database_name.db
# Done.
# [('MewtwoMega Mewtwo X', 'Psychic', 780, None),
#  ('MewtwoMega Mewtwo Y', 'Psychic', 780, None),
#  ('RayquazaMega Rayquaza', 'Dragon', 780, None),
#  ('MewtwoMega Mewtwo X', 'Psychic', 780, 1),
#  ('MewtwoMega Mewtwo Y', 'Psychic', 780, 1),
#  ('RayquazaMega Rayquaza', 'Dragon', 780, 3),
#  ('MewtwoMega Mewtwo X', 'Psychic', 780, 1),
#  ('MewtwoMega Mewtwo Y', 'Psychic', 780, 1),
#  ('RayquazaMega Rayquaza', 'Dragon', 780, 3),
#  ('MewtwoMega Mewtwo X', 'Psychic', 780, 1),
#  ('MewtwoMega Mewtwo Y', 'Psychic', 780, 1),
#  ('RayquazaMega Rayquaza', 'Dragon', 780, 3)]

# %%
# %sql Alter table strongestPokemon ADD Generation Integer;
# Out:
#  * sqlite:///your_database_name.db
# (sqlite3.OperationalError) duplicate column name: Generation
# [SQL: Alter table strongestPokemon ADD Generation Integer;]
# (Background on this error at: https://sqlalche.me/e/20/e3q8)

# %%
% SELECT * from strongestPokemon
# Out:
# UsageError: Line magic function `%` not found.

# %%
# %sql SELECT* from strongestPokemon
# Out:
#  * sqlite:///your_database_name.db
# Done.
# [('MewtwoMega Mewtwo X', 'Psychic', 780, None),
#  ('MewtwoMega Mewtwo Y', 'Psychic', 780, None),
#  ('RayquazaMega Rayquaza', 'Dragon', 780, None),
#  ('MewtwoMega Mewtwo X', 'Psychic', 780, 1),
#  ('MewtwoMega Mewtwo Y', 'Psychic', 780, 1),
#  ('RayquazaMega Rayquaza', 'Dragon', 780, 3),
#  ('MewtwoMega Mewtwo X', 'Psychic', 780, 1),
#  ('MewtwoMega Mewtwo Y', 'Psychic', 780, 1),
#  ('RayquazaMega Rayquaza', 'Dragon', 780, 3),
#  ('MewtwoMega Mewtwo X', 'Psychic', 780, 1),
#  ('MewtwoMega Mewtwo Y', 'Psychic', 780, 1),
#  ('RayquazaMega Rayquaza', 'Dragon', 780, 3)]

# %%
for index, row in strongest_pokemon.iterrows():
    name=row['Name']
    poke_type=row['Type 1']
    total=row['Total']
    Generation=row['Generation']

    # %sql INSERT INTO strongestPokemon (name, type, total,Generation) VALUES (:name, :poke_type, :total,:Generation)
# Out:
#  * sqlite:///your_database_name.db
# 1 rows affected.
#  * sqlite:///your_database_name.db
# 1 rows affected.
#  * sqlite:///your_database_name.db
# 1 rows affected.

# %%
SELECT *from strongestPokemon
# Out:
#   Cell In[33], line 1
#     SELECT *from strongestPokemon
#             ^
# SyntaxError: invalid syntax

# %% [raw]
# *sql Select From strongestPokemon

# %%
# %sql SELECT FROM strongestPokemon
# Out:
#  * sqlite:///your_database_name.db
# (sqlite3.OperationalError) near "FROM": syntax error
# [SQL: SELECT FROM strongestPokemon]
# (Background on this error at: https://sqlalche.me/e/20/e3q8)

# %%
df=pd.read_csv('pokemon_data.csv')

# %%
df.head()
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %%
df['Total']=df['Attack']+df['HP']+df['Defense']+df['Sp. Atk']+df['Speed']+df['Sp. Def']
df.to_csv('file1.csv')
df.fillna('None',inplace=True)

# %%
df.head(5)
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire    None  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary  Total
# 0       65     45           1      False    318
# 1       80     60           1      False    405
# 2      100     80           1      False    525
# 3      120     80           1      False    625
# 4       50     65           1      False    309

# %%
Legendary=df[df['Legendary']==True]

# %%
print(Legendary)
# Out:
#        #                 Name    Type 1    Type 2   HP  Attack  Defense  \
# 156  144             Articuno       Ice    Flying   90      85      100
# 157  145               Zapdos  Electric    Flying   90      90       85
# 158  146              Moltres      Fire    Flying   90     100       90
# 162  150               Mewtwo   Psychic      None  106     110       90
# 163  150  MewtwoMega Mewtwo X   Psychic  Fighting  106     190      100
# ..   ...                  ...       ...       ...  ...     ...      ...
# 795  719              Diancie      Rock     Fairy   50     100      150
# 796  719  DiancieMega Diancie      Rock     Fairy   50     160      110
# 797  720  HoopaHoopa Confined   Psychic     Ghost   80     110       60
# 798  720   HoopaHoopa Unbound   Psychic      Dark   80     160       60
# 799  721            Volcanion      Fire     Water   80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  Total
# ...

# %%
#Table of Legendary
# %%sql
CREATE TABLE Legendary(name Varchar(100),
                             Type1 Varchar(100),
                             Type2 varchar(100),
                             Generation int);
# Out:
#   Cell In[42], line 3
#     CREATE TABLE Legendary(name Varchar(100),
#            ^
# SyntaxError: invalid syntax

# %%
# %sql SELECT * FROM Legendary
# Out:
#  * sqlite:///your_database_name.db
# Done.
# [('Articuno', 'Ice', 'Flying', 1, 580, 85, 100, 95, 125, 90, 85),
#  ('Zapdos', 'Electric', 'Flying', 1, 580, 90, 85, 125, 90, 90, 100),
#  ('Moltres', 'Fire', 'Flying', 1, 580, 100, 90, 125, 85, 90, 90),
#  ('Mewtwo', 'Psychic', 'None', 1, 680, 110, 90, 154, 90, 106, 130),
#  ('MewtwoMega Mewtwo X', 'Psychic', 'Fighting', 1, 780, 190, 100, 154, 100, 106, 130),
#  ('MewtwoMega Mewtwo Y', 'Psychic', 'None', 1, 780, 150, 70, 194, 120, 106, 140),
#  ('Raikou', 'Electric', 'None', 2, 580, 85, 75, 115, 100, 90, 115),
#  ('Entei', 'Fire', 'None', 2, 580, 115, 85, 90, 75, 115, 100),
#  ('Suicune', 'Water', 'None', 2, 580, 75, 115, 90, 115, 100, 85),
#  ('Lugia', 'Psychic', 'Flying', 2, 680, 90, 130, 90, 154, 106, 110),
#  ('Ho-oh', 'Fire', 'Flying', 2, 680, 130, 90, 110, 154, 106, 90),
#  ('Regirock', 'Rock', 'None', 3, 580, 100, 200, 50, 100, 80, 50),
#  ('Regice', 'Ice', 'None', 3, 580, 50, 100, 100, 200, 80, 50),
# ...

# %%
# %sql SELECT name FROM LEGENDARY WHERE Generation=1
# Out:
#  * sqlite:///your_database_name.db
# Done.
# [('Articuno',),
#  ('Zapdos',),
#  ('Moltres',),
#  ('Mewtwo',),
#  ('MewtwoMega Mewtwo X',),
#  ('MewtwoMega Mewtwo Y',)]

# %%
df_filtered = df[~df['Name'].str.contains('Mega')]

# %%
# %sql SELECT name,Generation,Type1 FROM LEGENDARY WHERE Generation=2
# Out:
#  * sqlite:///your_database_name.db
# Done.
# [('Raikou', 2, 'Electric'),
#  ('Entei', 2, 'Fire'),
#  ('Suicune', 2, 'Water'),
#  ('Lugia', 2, 'Psychic'),
#  ('Ho-oh', 2, 'Fire')]

# %%
# %sql Alter TABLE 'Legendary' ADD HP INTEGER, Defense INTEGER,spAttack INTEGER,spDefense INTEGER,speed INTEGER
# Out:
#  * sqlite:///your_database_name.db
# (sqlite3.OperationalError) near ",": syntax error
# [SQL: Alter TABLE 'Legendary' ADD HP INTEGER, Defense INTEGER,spAttack INTEGER,spDefense INTEGER,speed INTEGER]
# (Background on this error at: https://sqlalche.me/e/20/e3q8)

# %%
# %sql Alter TABLE 'Legendary' ADD HP INTEGER, Defense INTEGER,spAttack INTEGER,spDefense INTEGER,speed INTEGER;
# Out:
#  * sqlite:///your_database_name.db
# (sqlite3.OperationalError) near ",": syntax error
# [SQL: Alter TABLE 'Legendary' ADD HP INTEGER, Defense INTEGER,spAttack INTEGER,spDefense INTEGER,speed INTEGER;]
# (Background on this error at: https://sqlalche.me/e/20/e3q8)

# %%
# %sql SELECT * FROM strongestPokemon
# Out:
#  * sqlite:///your_database_name.db
# Done.
# [('MewtwoMega Mewtwo X', 'Psychic', 780, None),
#  ('MewtwoMega Mewtwo Y', 'Psychic', 780, None),
#  ('RayquazaMega Rayquaza', 'Dragon', 780, None),
#  ('MewtwoMega Mewtwo X', 'Psychic', 780, 1),
#  ('MewtwoMega Mewtwo Y', 'Psychic', 780, 1),
#  ('RayquazaMega Rayquaza', 'Dragon', 780, 3),
#  ('MewtwoMega Mewtwo X', 'Psychic', 780, 1),
#  ('MewtwoMega Mewtwo Y', 'Psychic', 780, 1),
#  ('RayquazaMega Rayquaza', 'Dragon', 780, 3),
#  ('MewtwoMega Mewtwo X', 'Psychic', 780, 1),
#  ('MewtwoMega Mewtwo Y', 'Psychic', 780, 1),
#  ('RayquazaMega Rayquaza', 'Dragon', 780, 3),
#  ('MewtwoMega Mewtwo X', 'Psychic', 780, 1),
#  ('MewtwoMega Mewtwo Y', 'Psychic', 780, 1),
#  ('RayquazaMega Rayquaza', 'Dragon', 780, 3)]

# %%
# %sql ALTER TABLE Legendary ADD Total Integer;
# Out:
#  * sqlite:///your_database_name.db
# (sqlite3.OperationalError) duplicate column name: Total
# [SQL: ALTER TABLE Legendary ADD Total Integer;]
# (Background on this error at: https://sqlalche.me/e/20/e3q8)

# %%
# %sql Alter Table Legendary ADD Attack integer;
# Out:
#  * sqlite:///your_database_name.db
# (sqlite3.OperationalError) duplicate column name: Attack
# [SQL: Alter Table Legendary ADD Attack integer;]
# (Background on this error at: https://sqlalche.me/e/20/e3q8)

# %%
# %sql Alter Table Legendary ADD Defense integer;
# Out:
#  * sqlite:///your_database_name.db
# (sqlite3.OperationalError) duplicate column name: Defense
# [SQL: Alter Table Legendary ADD Defense integer;]
# (Background on this error at: https://sqlalche.me/e/20/e3q8)

# %%
# %sql Alter Table Legendary ADD SpAttack integer;
# Out:
#  * sqlite:///your_database_name.db
# (sqlite3.OperationalError) duplicate column name: SpAttack
# [SQL: Alter Table Legendary ADD SpAttack integer;]
# (Background on this error at: https://sqlalche.me/e/20/e3q8)

# %%
# %sql Alter Table Legendary ADD SpDefense integer;
# Out:
#  * sqlite:///your_database_name.db
# (sqlite3.OperationalError) duplicate column name: SpDefense
# [SQL: Alter Table Legendary ADD SpDefense integer;]
# (Background on this error at: https://sqlalche.me/e/20/e3q8)

# %%
# %sql Alter Table Legendary ADD Speed integer;
# Out:
#  * sqlite:///your_database_name.db
# (sqlite3.OperationalError) duplicate column name: Speed
# [SQL: Alter Table Legendary ADD Speed integer;]
# (Background on this error at: https://sqlalche.me/e/20/e3q8)

# %%
Select *FROM Legendary
# Out:
#   Cell In[56], line 1
#     Select *FROM Legendary
#                  ^
# SyntaxError: invalid syntax

# %%
# %sql SELECT *from Legendary
# Out:
#  * sqlite:///your_database_name.db
# Done.
# [('Articuno', 'Ice', 'Flying', 1, 580, 85, 100, 95, 125, 90, 85),
#  ('Zapdos', 'Electric', 'Flying', 1, 580, 90, 85, 125, 90, 90, 100),
#  ('Moltres', 'Fire', 'Flying', 1, 580, 100, 90, 125, 85, 90, 90),
#  ('Mewtwo', 'Psychic', 'None', 1, 680, 110, 90, 154, 90, 106, 130),
#  ('MewtwoMega Mewtwo X', 'Psychic', 'Fighting', 1, 780, 190, 100, 154, 100, 106, 130),
#  ('MewtwoMega Mewtwo Y', 'Psychic', 'None', 1, 780, 150, 70, 194, 120, 106, 140),
#  ('Raikou', 'Electric', 'None', 2, 580, 85, 75, 115, 100, 90, 115),
#  ('Entei', 'Fire', 'None', 2, 580, 115, 85, 90, 75, 115, 100),
#  ('Suicune', 'Water', 'None', 2, 580, 75, 115, 90, 115, 100, 85),
#  ('Lugia', 'Psychic', 'Flying', 2, 680, 90, 130, 90, 154, 106, 110),
#  ('Ho-oh', 'Fire', 'Flying', 2, 680, 130, 90, 110, 154, 106, 90),
#  ('Regirock', 'Rock', 'None', 3, 580, 100, 200, 50, 100, 80, 50),
#  ('Regice', 'Ice', 'None', 3, 580, 50, 100, 100, 200, 80, 50),
# ...

# %%
df.head()
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire    None  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary  Total
# 0       65     45           1      False    318
# 1       80     60           1      False    405
# 2      100     80           1      False    525
# 3      120     80           1      False    625
# 4       50     65           1      False    309

# %%
# %sql SELECT * FROM LEGENDARY WHERE GENERATION=1
# Out:
#  * sqlite:///your_database_name.db
# Done.
# [('Articuno', 'Ice', 'Flying', 1, 580, 85, 100, 95, 125, 90, 85),
#  ('Zapdos', 'Electric', 'Flying', 1, 580, 90, 85, 125, 90, 90, 100),
#  ('Moltres', 'Fire', 'Flying', 1, 580, 100, 90, 125, 85, 90, 90),
#  ('Mewtwo', 'Psychic', 'None', 1, 680, 110, 90, 154, 90, 106, 130),
#  ('MewtwoMega Mewtwo X', 'Psychic', 'Fighting', 1, 780, 190, 100, 154, 100, 106, 130),
#  ('MewtwoMega Mewtwo Y', 'Psychic', 'None', 1, 780, 150, 70, 194, 120, 106, 140)]

# %%
# %sql drop table Legendary;
# Out:
#  * sqlite:///your_database_name.db
# Done.
# []

# %%
# %%sql CREATE TABLE Legendary(name Varchar(100),
#                              Type1 Varchar(100),
#                              Type2 varchar(100),
#                              Generation int,Total int,Attack int,Defense int,SpAttack int,spDefense int,Hp int, speed int);
# Out:
#  * sqlite:///your_database_name.db
# (sqlite3.OperationalError) table Legendary already exists
# [SQL: CREATE TABLE Legendary(name Varchar(100),
#                              Type1 Varchar(100),
#                              Type2 varchar(100),
#                              Generation int,Total int,Attack int,Defense int,SpAttack int,spDefense int,Hp int, speed int);]
# (Background on this error at: https://sqlalche.me/e/20/e3q8)

# %% [raw]
# for index,row in Legendary.iterrows():
#     Name=row['Name']
#     Generation=row['Generation']
#     Type1=row['Type 1' ]
#     Type2=row['Type 2' ]
#     Attack=row['Attack']
#     Defense=row['Defense']
#     Speed=row['Speed']
#     SpAttack=row['Sp. Atk']
#     SpDefense=row['Sp. Def']
#     Total=row['Total']
#     Hp=row['HP']
#
#     %sql INSERT INTO Legendary(Name,Type1,Type2,Generation,Total,Attack,Defense,SpAttack,spDefense,HP,Speed)Values(:Name,:Type1,:Type2,:Generation,:Total,:Attack,:Defense,:SpAttack,:SpDefense,:Hp,:Speed)

# %%
SELECT Name FROM LEGENDARY WHERE GENERATION='1'
# Out:
#   Cell In[63], line 1
#     SELECT Name FROM LEGENDARY WHERE GENERATION='1'
#            ^
# SyntaxError: invalid syntax

# %%
# %sql SELECT * FROM LEGENDARY WHERE GENERATION='1'
# Out:
#  * sqlite:///your_database_name.db
# Done.
# [('Articuno', 'Ice', 'Flying', 1, 580, 85, 100, 95, 125, 90, 85),
#  ('Zapdos', 'Electric', 'Flying', 1, 580, 90, 85, 125, 90, 90, 100),
#  ('Moltres', 'Fire', 'Flying', 1, 580, 100, 90, 125, 85, 90, 90),
#  ('Mewtwo', 'Psychic', 'None', 1, 680, 110, 90, 154, 90, 106, 130),
#  ('MewtwoMega Mewtwo X', 'Psychic', 'Fighting', 1, 780, 190, 100, 154, 100, 106, 130),
#  ('MewtwoMega Mewtwo Y', 'Psychic', 'None', 1, 780, 150, 70, 194, 120, 106, 140)]

# %% [markdown]
#  brew install pandoc

# %%
## Finding Outliers in our data who based on the total scores

# %%
df=df.sorted()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/xs/s1wxvlk149d7b262wydfvmr00000gn/T/ipykernel_7506/1423373682.py in ?()
# ----> 1 df=df.sorted()
#
# ~/anaconda3/lib/python3.11/site-packages/pandas/core/generic.py in ?(self, name)
#    5985             and name not in self._accessors
#    5986             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5987         ):
#    5988             return self[name]
# -> 5989         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'sorted'

# %%
df=df.sort_values('Total')

# %%
df.describe()
# Out:
#                 #          HP      Attack     Defense     Sp. Atk     Sp. Def  \
# count  800.000000  800.000000  800.000000  800.000000  800.000000  800.000000
# mean   362.813750   69.258750   79.001250   73.842500   72.820000   71.902500
# std    208.343798   25.534669   32.457366   31.183501   32.722294   27.828916
# min      1.000000    1.000000    5.000000    5.000000   10.000000   20.000000
# 25%    184.750000   50.000000   55.000000   50.000000   49.750000   50.000000
# 50%    364.500000   65.000000   75.000000   70.000000   65.000000   70.000000
# 75%    539.250000   80.000000  100.000000   90.000000   95.000000   90.000000
# max    721.000000  255.000000  190.000000  230.000000  194.000000  230.000000
#
#             Speed  Generation      Total
# count  800.000000   800.00000  800.00000
# mean    68.277500     3.32375  435.10250
# std     29.060474     1.66129  119.96304
# min      5.000000     1.00000  180.00000
# 25%     45.000000     2.00000  330.00000
# ...

# %%
sns.set_style("whitegrid")

sns.boxplot(showfliers=True,data=df['Total'],x=df['Total'],meanprops={"marker": "o"},notch=True,  medianprops={"color": "r", "linewidth": 2}, boxprops={"facecolor": (.3, .5, .7, .5)})

plt.title('Box and whisker Diagram of ALL Pokemon')

median=df['Total'].median()
df.describe()
lowerQuartileofTotal=330
UpperQuartileofTotal=515
InterQuartileofTotal=UpperQuartileofTotal-lowerQuartileofTotal
lowerBoundary=lowerQuartileofTotal-(1.5*InterQuartileofTotal)
upperBoundary=UpperQuartileofTotal+(1.5*InterQuartileofTotal)

print(lowerBoundary)
print(upperBoundary)

outliers=df[df['Total']==lowerBoundary]
# Out:
# 52.5
# 792.5

# %% [raw]
# ##Lets find out the strongest pokemon who are not legendary,  them into the SQL table
#
# strongest_non_legendary = df[(df['Legendary'] == False) & (df['Total'] > df['Total'].mean())]
#
# #%sql CREATE TABLE nonLegendary(Name,Total,Attack,Defence,HP,SpAttack,SpDefence,Speed,Generation,Type1,Type2);
#
# for index,row in strongest_non_legendary.iterrows():
#     Name=row['Name']
#     Generation=row['Generation']
#     Type1=row['Type 1' ]
#     Type2=row['Type 2' ]
#     Attack=row['Attack']
#     Defense=row['Defense']
#     Speed=row['Speed']
#     SpAttack=row['Sp. Atk']
#     SpDefense=row['Sp. Def']
#     Total=row['Total']
#     Hp=row['HP']
#
#     %sql INSERT INTO nonLegendary(Name,Total,Attack,Defence,HP,SpAttack,SpDefence,Speed,Generation,Type1,Type2)Values(:Name,:Total,:Attack,:Defense,:Hp,:SpAttack,:SpDefense,:Speed,:Generation,:Type1,:Type2)

# %% [raw]
# #lets find out the distrubutions of attack,defence of the  legendary pokemon
#
# %sql SELECT * FROM nonlegendary WHERE total>600
#
# #lets find out the distrubutions of attack,defence of the  legendary pokemon
#
#
# print("Legendary Pokemon")
#
# fig, axs = plt.subplots(2, 3, figsize=(15, 10))
#
#
# plt.subplot(2, 3, 1)
# sns.histplot(Legendary['Attack'],kde=True)
#
#
#
# plt.subplot(2, 3, 2)
# sns.histplot(Legendary['Defense'],kde=True)
#
#
# plt.subplot(2, 3, 3)
# sns.histplot(Legendary['Speed'],kde=True)
#
#
# plt.subplot(2, 3, 4)
# sns.histplot(Legendary['HP'],kde=True)
#
#
# plt.subplot(2, 3, 5)
# sns.histplot(Legendary['Sp. Atk'],kde=True)
#
#
# plt.subplot(2, 3, 6)
# sns.histplot(Legendary['Sp. Def'],kde=True)
#
# plt.show()
#
# plt.tight_layout()
#
#
# #now lets see the same stats for the non Legendary Pokemon
#
#
# print("Pokemon Who have a mean greater than the total score but are not legendaries")
#
# fig, axs = plt.subplots(2, 3, figsize=(15, 10))
#
#
# plt.subplot(2, 3, 1)
# sns.histplot(strongest_non_legendary['Attack'],kde=True)
#
#
#
# plt.subplot(2, 3, 2)
# sns.histplot(strongest_non_legendary['Defense'],kde=True)
#
#
# plt.subplot(2, 3, 3)
# sns.histplot(strongest_non_legendary['Speed'],kde=True)
#
#
# plt.subplot(2, 3, 4)
# sns.histplot(strongest_non_legendary['HP'],kde=True)
#
#
# plt.subplot(2, 3, 5)
# sns.histplot(strongest_non_legendary['Sp. Atk'],kde=True)
#
#
# plt.subplot(2, 3, 6)
# sns.histplot(strongest_non_legendary['Sp. Def'],kde=True)
#
# plt.show()
#
# plt.tight_layout()
#
#
#
# nonLegendary=df[df['Legendary']==False]
#
# print("All of the pokemon that are not legendarires")
# plt.subplot(2, 3, 1)
# sns.histplot(nonLegendary['Attack'],kde=True)
#
#
#
# plt.subplot(2, 3, 2)
# sns.histplot(nonLegendary['Defense'],kde=True)
#
#
# plt.subplot(2, 3, 3)
# sns.histplot(nonLegendary['Speed'],kde=True)
#
#
# plt.subplot(2, 3, 4)
# sns.histplot(nonLegendary['HP'],kde=True)
#
#
# plt.subplot(2, 3, 5)
# sns.histplot(nonLegendary['Sp. Atk'],kde=True)
#
#
# plt.subplot(2, 3, 6)
# sns.histplot(nonLegendary['Sp. Def'],kde=True)
#
# plt.show()
#
# plt.tight_layout()
#
# import seaborn as sns
# sns.boxplot(Legendary['Total'])
#
#
#
#
# # Now Lets put these non legendaries into an SQL table. It may help us later
#
# %sql  CREATE TABLE nonLeg(Name,Total,Attack,Defence,HP,SpAttack,SpDefence,Speed,Generation,Type1,Type2);
#
# for index,row in nonLegendary.iterrows():
#     Name=row['Name']
#     Generation=row['Generation']
#     Type1=row['Type 1' ]
#     Type2=row['Type 2' ]
#     Attack=row['Attack']
#     Defense=row['Defense']
#     Speed=row['Speed']
#     SpAttack=row['Sp. Atk']
#     SpDefense=row['Sp. Def']
#     Total=row['Total']
#     Hp=row['HP']
#
#     %sql INSERT INTO nonLeg(Name,Total,Attack,Defence,HP,SpAttack,SpDefence,Speed,Generation,Type1,Type2)Values(:Name,:Total,:Attack,:Defense,:Hp,:SpAttack,:SpDefense,:Speed,:Generation,:Type1,:Type2)

# %%
#Hp looks interesting in the pokemon who are not legendary verses the pokemon that are not legendaries and have a total greater than mean
#Lets analyze using the ratios of

HpRationonLeg=(nonLegendary['HP'].mean()/strongest_non_legendary['HP'].mean())
AttackRationonLeg=nonLegendary['Attack'].mean()/strongest_non_legendary['Attack'].mean()
DefenceRationonLeg=nonLegendary['Defense'].mean()/strongest_non_legendary['Defense'].mean()
print(HpRationonLeg)
print(AttackRationonLeg)
print(DefenceRationonLeg)


HpRatioLeg=(nonLegendary['HP'].mean()/Legendary['HP'].mean())
AttackRatioLeg=nonLegendary['Attack'].mean()/Legendary['Attack'].mean()
DefenceRatioLeg=nonLegendary['Defense'].mean()/Legendary['Defense'].mean()

print("")

print(HpRatioLeg)
print(AttackRatioLeg)
print(DefenceRatioLeg)


HpRatioLeg1=(strongest_non_legendary['HP'].mean()/Legendary['HP'].mean())
AttackRatioLeg1=strongest_non_legendary['Attack'].mean()/Legendary['Attack'].mean()
DefenceRatioLeg1=strongest_non_legendary['Defense'].mean()/Legendary['Defense'].mean()

print("")
print(HpRatioLeg1)
print(AttackRatioLeg1)
print(DefenceRatioLeg1)

# %%
#%sql SELECT Hp FROM Legendary
#%sql SElECT Hp From nonLegendary

# %%
##Lets analyze what is the correlation of attack of all of the pokemon.

correlationAttackwithDefence=df['Attack'].corr(df['Defense'])
correlationAttackwithSpeed=df['Attack'].corr(df['Speed'])
correlationAttackwithHp=df['Attack'].corr(df['HP'])
correlationAttackwithSpAttack=df['Attack'].corr(df['Sp. Atk'])
correlationAttackwithSpDefence=df['Attack'].corr(df['Sp. Def'])
correlationAttackwithTotal=df['Attack'].corr(df['Total'])


correlationAttackTotal={'Attack Correlation':[{'Defence':correlationAttackwithDefence},{'Speed':correlationAttackwithSpeed},{'Hp':correlationAttackwithHp}
                       ,{'SpAttack':correlationAttackwithSpAttack},{'SpDefence':correlationAttackwithSpDefence}]}
correlationAttackTotal=pd.DataFrame(correlationAttackTotal)



print(correlationAttackwithTotal)


print(correlationAttackTotal)

#It seems that Special Defence contributes to very low if the attack is high of a pokemon

#now it would be interesting to see what happens if we analyze other factors

correlationDefencewithAttack=df['Defense'].corr(df['Attack'])
correlationDefencewithSpeed=df['Defense'].corr(df['Speed'])
correlationDefencewithHp=df['Defense'].corr(df['HP'])
correlationDefencewithSpAttack=df['Defense'].corr(df['Sp. Atk'])
correlationDefencewithSpDefence=df['Defense'].corr(df['Sp. Def'])
correelationDefencewithTotal=df['Defense'].corr(df['Sp. Def'])

correlationDefenceTotal={'Defence Correlation':[{'Defence':correlationDefencewithAttack},{'Speed':correlationDefencewithSpeed},{'Hp':correlationDefencewithHp}
                       ,{'SpAttack':correlationDefencewithSpAttack},{'SpDefence':correlationDefencewithSpDefence}]}
correlationDefenceTotal=pd.DataFrame(correlationDefenceTotal)
print(correlationDefenceTotal)

#Now lets analyze speed

correlationSpeedwithAttack=df['Speed'].corr(df['Attack'])
correlationSpeedwithDefence=df['Speed'].corr(df['Defense'])
correlationSpeedwithHp=df['Speed'].corr(df['HP'])
correlationSpeedwithSpAttack=df['Speed'].corr(df['Sp. Atk'])
correlationSpeedwithSpDefence=df['Speed'].corr(df['Sp. Def'])

correlationSpeedTotal={'Speed Correlation':[{'Attack':correlationSpeedwithAttack},{'Defence':correlationSpeedwithDefence},{'Hp':correlationSpeedwithHp}
                       ,{'SpAttack':correlationSpeedwithSpAttack},{'SpDefence':correlationSpeedwithSpDefence}]}
correlationSpeedTotal=pd.DataFrame(correlationSpeedTotal)

print(correlationSpeedTotal)


#Based on the correlation it can be seen that defence and speed are independent

#Based on the correlation of speed and defence with Hp, it doesn't seem to influence much


#lets plot a graph of defence correlation  and speed correlation

sns.lineplot(x=df['Speed'],y=df['Defense'])

# Now lets plot the graph of Attack and Defense
plt.figure()
sns.lineplot(x=df['Attack'],y=df['Defense'])

# %%
correlationDefencewithAttack=df['Defense'].corr(df['Attack'])
correlationDefencewithSpeed=df['Defense'].corr(df['Speed'])
correlationDefencewithHp=df['Defense'].corr(df['HP'])
correlationDefenceTotal={'Defence Correlation':[{'Attack':correlationDefencewithAttack},{'Speed':correlationDefencewithSpeed},{'Hp':correlationDefencewithHp}]}
correlationDefenceTotal=pd.DataFrame(correlationDefenceTotal)
print(correlationDefenceTotal)

# %%
pearson_attack_defense= stats.pearsonr(df['Attack'], df['Defense'])

# %%
import scipy.stats as stats

# %%
pearson_attack_defense= stats.pearsonr(df['Attack'], df['Defense'])

# %%
print(pearson_attack_defense)

# %%
# %sql SELECT * FROM nonleg DESC Total
# Out:
#  * sqlite:///your_database_name.db
# (sqlite3.OperationalError) near "Total": syntax error
# [SQL: SELECT * FROM nonleg DESC Total]
# (Background on this error at: https://sqlalche.me/e/20/e3q8)

# %%
# %sql Drop table nonLeg
# Out:
#  * sqlite:///your_database_name.db
# Done.
# []

# %%
# %sql  CREATE TABLE nonLeg(Name,Total,Attack,Defence,HP,SpAttack,SpDefence,Speed,Generation,Type1,Type2);

for index,row in nonLegendary.iterrows():
    Name=row['Name']
    Generation=row['Generation']
    Type1=row['Type 1' ]
    Type2=row['Type 2' ]
    Attack=row['Attack']
    Defense=row['Defense']
    Speed=row['Speed']
    SpAttack=row['Sp. Atk']
    SpDefense=row['Sp. Def']
    Total=row['Total']
    Hp=row['HP']

    # %sql INSERT INTO nonLeg(Name,Total,Attack,Defence,HP,SpAttack,SpDefence,Speed,Generation,Type1,Type2)Values(:Name,:Total,:Attack,:Defense,:Hp,:SpAttack,:SpDefense,:Speed,:Generation,:Type1,:Type2)

# %%
#Lets see the pokemon that are the strongest based on its type who are not legendaries

# %sql SELECT Type1,Count(*) FROM nonleg Group By Type1

#Now Lets see the stongest Legendaries based on their type.
# %sql SELECT type1,Count(*) FROM legendary GROUP BY type1

#Very interesting data. The data shows us that water type is the most common among the non legendaries
#and Rock type is the most common in Legendaries

#Now lets see what type has the most pokemon and is the strongest pokemon who has a higher mean than the total but is not legendary

# %sql SELECT type1,Count(*) FROM nonlegendary GROUP BY type1

#it seems like water pokemon is still dominant in this group too the second place is normal and the third is bug

#As we move to stronger pokemon bug pokemon decreases.

# %%
#interesting thing we can find that how much does the evolution changes the stats of pokemon

# %%
evolution=pd.read_csv('evolution1.csv')

# %%
evolution.head()
evolution.fillna('None', inplace=True)

# %%
evolution.head()
# Out:
#       Stage_1   Stage_2 Stage_3
# 0     Nincada  Shedinja    None
# 1     Scyther   Kleavor    None
# 2     Scyther    Scizor    None
# 3  Type: Null  Silvally    None
# 4    Stantler   Wyrdeer    None

# %%
#Lets Create a table of SQL with the evolution

# %sql Create Table evolution(Name varchar(50), evolution1 varchar(50), evolution2 varchar(50));

for  index,row in evolution.iterrows():
    Name=row['Stage_1']
    Firstevolve=row['Stage_2']
    Secondevolve=row['Stage_3']
    # %sql INSERT INTO evolution(Name,evolution1,evolution2)Values(:Name,:Firstevolve,:Secondevolve)

# %%
# Now lets try to display the evolution table
SELECT * FROM evolution

# %%
# %sql SELECT * FROM evolution

# %%
# %sql SELECT * FROM evolution
# Out:
#  * sqlite:///your_database_name.db
# Done.
# [('Nincada', 'Shedinja', 'None'),
#  ('Scyther', 'Kleavor', 'None'),
#  ('Scyther', 'Scizor', 'None'),
#  ('Type: Null', 'Silvally', 'None'),
#  ('Stantler', 'Wyrdeer', 'None'),
#  ('Misdreavus', 'Mismagius', 'None'),
#  ('Basculin', 'Basculegion', 'None'),
#  ('Qwilfish', 'Overqwil', 'None'),
#  ('Gligar', 'Gliscor', 'None'),
#  ('Sneasel', 'Sneasler', 'None'),
#  ('Sneasel', 'Weavile', 'None'),
#  ('Ponyta', 'Rapidash', 'None'),
#  ('Tangela', 'Tangrowth', 'None'),
#  ('Corsola', 'Cursola', 'None'),
#  ('Murkrow', 'Honchkrow', 'None'),
#  ('Wailmer', 'Wailord', 'None'),
#  ('Poipole', 'Naganadel', 'None'),
#  ('Mudbray', 'Mudsdale', 'None'),
#  ('Espurr', 'Meowstic', 'None'),
#  ('Woobat', 'Swoobat', 'None'),
#  ('Yanma', 'Yanmega', 'None'),
#  ('Onix', 'Steelix', 'None'),
#  ('Cubone', 'Marowak', 'None'),
#  ('Lickitung', 'Lickilicky', 'None'),
#  ('Aipom', 'Ambipom', 'None'),
#  ("Farfetch'd", "Sirfetch'd", 'None'),
# ...

# %%
# %sql SELECT Name FROM evolution
# Out:
#  * sqlite:///your_database_name.db
# Done.
# [('Nincada',),
#  ('Scyther',),
#  ('Scyther',),
#  ('Type: Null',),
#  ('Stantler',),
#  ('Misdreavus',),
#  ('Basculin',),
#  ('Qwilfish',),
#  ('Gligar',),
#  ('Sneasel',),
#  ('Sneasel',),
#  ('Ponyta',),
#  ('Tangela',),
#  ('Corsola',),
#  ('Murkrow',),
#  ('Wailmer',),
#  ('Poipole',),
#  ('Mudbray',),
#  ('Espurr',),
#  ('Woobat',),
#  ('Yanma',),
#  ('Onix',),
#  ('Cubone',),
#  ('Lickitung',),
#  ('Aipom',),
#  ("Farfetch'd",),
#  ('Porygon',),
#  ('Spritzee',),
#  ('Buneary',),
#  ('Litleo',),
#  ('Vullaby',),
#  ('Munchlax',),
#  ('Chinchou',),
#  ('Finneon',),
#  ('Anorith',),
#  ('Kabuto',),
#  ('Lileep',),
#  ('Omanyte',),
#  ('Tirtouga',),
#  ('Nosepass',),
#  ('Scraggy',),
#  ('Clamperl',),
#  ('Clamperl',),
#  ('Mantyke',),
#  ('Goldeen',),
#  ('Swirlix',),
#  ('Bonsly',),
#  ('Archen',),
#  ('Crabrawler',),
#  ('Cranidos',),
#  ('Shieldon',),
#  ('Cacnea',),
#  ('Deerling',),
#  ('Morelull',),
#  ('Paras',),
# ...

# %%
# %sql SELECT  FROM nonLegendary JOIN evolution ON nonLegendary.name=evolution.name
# Out:
#  * sqlite:///your_database_name.db
# (sqlite3.OperationalError) near "FROM": syntax error
# [SQL: SELECT FROM nonLegendary JOIN evolution ON nonLegendary.name=evolution.name]
# (Background on this error at: https://sqlalche.me/e/20/e3q8)

# %%
import random

# %%
 #Mean before taking;

# %%
# %%sql SELECT  distinct evolution.name
# FROM evolution
# JOIN nonLegendary ON nonLegendary.name = evolution.name;
# Out:
#  * sqlite:///your_database_name.db
# Done.
# [('Scyther',), ('Stantler',), ('Basculin',)]

# %%
# %sql SELECT * FROM nonleg
# Out:
#  * sqlite:///your_database_name.db
# Done.
# [('Sunkern', 180, 30, 30, 30, 30, 30, 30, 2, 'Grass', 'None'),
#  ('Azurill', 190, 20, 40, 50, 20, 40, 20, 3, 'Normal', 'Fairy'),
#  ('Kricketot', 194, 25, 41, 37, 25, 41, 25, 4, 'Bug', 'None'),
#  ('Wurmple', 195, 45, 35, 45, 20, 30, 20, 3, 'Bug', 'None'),
#  ('Weedle', 195, 35, 30, 40, 20, 20, 50, 1, 'Bug', 'Poison'),
#  ('Caterpie', 195, 30, 35, 45, 20, 20, 45, 1, 'Bug', 'None'),
#  ('Ralts', 198, 25, 25, 28, 45, 35, 40, 3, 'Psychic', 'Fairy'),
#  ('Scatterbug', 200, 35, 40, 38, 27, 25, 35, 6, 'Bug', 'None'),
#  ('Magikarp', 200, 10, 55, 20, 15, 20, 80, 1, 'Water', 'None'),
#  ('Feebas', 200, 15, 20, 20, 10, 55, 80, 3, 'Water', 'None'),
#  ('Cascoon', 205, 35, 55, 50, 25, 25, 15, 3, 'Bug', 'None'),
#  ('Pichu', 205, 40, 15, 20, 35, 35, 60, 2, 'Electric', 'None'),
#  ('Kakuna', 205, 25, 50, 45, 25, 25, 35, 1, 'Bug', 'Poison'),
#  ('Metapod', 205, 20, 55, 50, 25, 25, 30, 1, 'Bug', 'None'),
# ...

# %%
#sql SELECT nonLeg.name,nonLeg.Total,AVG(nonLeg.Total)
#FROM nonLeg
#JOIN evolution ON evolution.name=nonLeg.name
# Out:
# UsageError: Line magic function `%%sql` not found.

# %%
# %%sql  SELECT nonLeg.Total,AVG(Total)
# FROM nonLeg
# JOIN evolution ON evolution.name=nonLeg.name
# Out:
#  * sqlite:///your_database_name.db
# Done.
# [(180, 306.2909090909091)]

# %%
# %%sql  SELECT nonLeg.Total,AVG(Total)
# FROM nonLeg
# JOIN evolution ON evolution.evolution1=nonLeg.name
# Out:
#  * sqlite:///your_database_name.db
# Done.
# [(205, 446.09811320754716)]

# %%
# %%sql  SELECT nonLeg.Total,AVG(Total)
# FROM nonLeg
# JOIN evolution ON evolution.evolution2=nonLeg.name
# Out:
#  * sqlite:///your_database_name.db
# Done.
# [(385, 514.816091954023)]

# %% [markdown]
# ## Based on the data it can be seen that on average when a pokemon evolves its stats increase to around 45%
# ## When a pokemon goes to generation 3 from generation 2 it only increases to 15%.

# %%
# Out:
# 1.32
